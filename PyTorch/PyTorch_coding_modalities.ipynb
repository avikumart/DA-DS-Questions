# %% [markdown]
# <a href="https://colab.research.google.com/github/avikumart/DA-DS-Questions/blob/main/PyTorch/PyTorch_coding_modalities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
x = torch.tensor(3.0, requires_grad=True)
y = torch.tensor(4.0, requires_grad=True)
z = x + y
z.backward()
print(x.grad)
print(y.grad)
# Out:
# tensor(1.)
# tensor(1.)

# %%
x1 = torch.tensor(3.0, requires_grad=True)
y1 = x **2 + 2*x

y1.backward()

# %%
# custome datapipeline

from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):
    def __init__(self, size=100):
        self.data = torch.randn(size, 10)
        self.labels = torch.randint(0, 2, (size,))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# Instantiate and pass to DataLoader
dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size=16, shuffle=True, num_workers=2, pin_memory=True)
