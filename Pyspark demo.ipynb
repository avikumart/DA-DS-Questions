# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Pyspark Demo").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# WARNING: package sun.security.action not in java.base
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/03 16:11:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# WARNING: A terminally deprecated method in sun.misc.Unsafe has been called
# WARNING: sun.misc.Unsafe::arrayBaseOffset has been called by org.apache.spark.unsafe.Platform (file:/Users/avikumart/Documents/GitHub/DA-DS-Questions/.venv/lib/python3.11/site-packages/pyspark/jars/spark-unsafe_2.13-4.1.2.jar)
# WARNING: Please consider reporting this to the maintainers of class org.apache.spark.unsafe.Platform
# WARNING: sun.misc.Unsafe::arrayBaseOffset will be removed in a future release

# %%
# Sample data
data = [
    ("Alice", "Data Science", 95000),
    ("Bob", "Engineering", 80000),
    ("Charlie", "Data Science", 105000),
    ("David", "Marketing", 60000),
    ("Eva", "Engineering", 85000)
]

# Column names
columns = ["Name", "Department", "Salary"]

# Create DataFrame
df = spark.createDataFrame(data, schema=columns)

# Show the data (Defaults to top 20 rows)
df.show()
# Out:
# 26/06/03 16:18:46 WARN FileSystem: Cannot load filesystem
# java.util.ServiceConfigurationError: org.apache.hadoop.fs.FileSystem: Provider org.apache.hadoop.fs.viewfs.ViewFileSystem could not be instantiated
# 	at java.base/java.util.ServiceLoader.fail(ServiceLoader.java:552)
# 	at java.base/java.util.ServiceLoader$ProviderImpl.newInstance(ServiceLoader.java:712)
# 	at java.base/java.util.ServiceLoader$ProviderImpl.get(ServiceLoader.java:672)
# 	at java.base/java.util.ServiceLoader$2.next(ServiceLoader.java:1256)
# 	at org.apache.hadoop.fs.FileSystem.loadFileSystems(FileSystem.java:3525)
# 	at org.apache.hadoop.fs.FileSystem.getFileSystemClass(FileSystem.java:3562)
# 	at org.apache.hadoop.fs.FsUrlStreamHandlerFactory.<init>(FsUrlStreamHandlerFactory.java:77)
# 	at org.apache.spark.sql.internal.SharedState$.liftedTree2$1(SharedState.scala:209)
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Department: string (nullable = true)
#  |-- Salary: long (nullable = true)

# %%
df.describe().show()
# Out:
# +-------+-----+------------+------------------+
# |summary| Name|  Department|            Salary|
# +-------+-----+------------+------------------+
# |  count|    5|           5|                 5|
# |   mean| NULL|        NULL|           85000.0|
# | stddev| NULL|        NULL|16955.824957813165|
# |    min|Alice|Data Science|             60000|
# |    max|  Eva|   Marketing|            105000|
# +-------+-----+------------+------------------+

# %%
# Select specific columns and filter rows
print("Filtering for Data Science Department:")
df.select("Name", "Salary").filter(df.Department == "Data Science").show()

# Group by and aggregate (e.g., Average salary by department)
from pyspark.sql import functions as F

print("Average Salary by Department:")
df.groupBy("Department").agg(F.avg("Salary").alias("Avg_Salary")).show()
# Out:
# Filtering for Data Science Department:
# +-------+------+
# |   Name|Salary|
# +-------+------+
# |  Alice| 95000|
# |Charlie|105000|
# +-------+------+
#
# Average Salary by Department:
# +------------+----------+
# |  Department|Avg_Salary|
# +------------+----------+
# |Data Science|  100000.0|
# | Engineering|   82500.0|
# |   Marketing|   60000.0|
# +------------+----------+

# %%
# stop the Spark session
spark.stop()
